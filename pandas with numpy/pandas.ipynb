# %% [markdown]
# Pandas Series
#
# A Series is one-dimensional labeled array capabale of holding any datatype. the acis are collectively callled the index.

# %% [markdown]
# creating series:
# There are multiple ways to create a pandsa series: wes mechiney created the pandas(panel data)

# %%
import numpy as np
import pandas as pd

# %%
import numpy as np
import pandas as pd
labels=["b","a","c"]
my_list=[10,20,30]
arr=np.array([20,30,40])
d={10,20,30,40}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# b    10
# a    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    20
# 1    30
# 2    40
# dtype: int64

# %% [markdown]
# DATA FRAMES
# When you combine multiple series togather called dataframe
